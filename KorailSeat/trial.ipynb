# %%
from korail import *
# %matplotlib inline

ko = Korail()

# %%
# 날짜와 시간 입력
depart = "서울"
arrive = "부산"
date = "20170922"     # YYMMDD
time = "120000"       # hhmmss

# %%
# 현재 운행중인 차량 출력

ko.search_trains(depart, arrive, date, time)
ko.search_print_current()
# Out:
# 01 KTX		서울(12:00) - 부산(14:42)
# 02 KTX		서울(12:30) - 부산(15:07)
# 03 KTX-산천	서울(13:00) - 부산(15:45)
# 04 무궁화호	서울(13:03) - 부산(18:31)
# 05 KTX		서울(13:10) - 부산(16:15)
# 06 KTX		서울(13:20) - 부산(15:51)
# 07 KTX		서울(13:30) - 부산(16:10)
# 08 KTX		서울(13:55) - 부산(16:22)
# 09 KTX		서울(14:00) - 부산(16:27)
# 10 ITX-새마을	서울(14:05) - 부산(18:59)

# %%
# 차량 선택 및 검색
ko.set_checkout()

print("\n")

ko.search_seat()
# Out:
# Select number : 4
# =============== SELECTED TRAIN INFO ===============
# 무궁화호	서울(13:03) - 부산(18:31)
#
#
# =============== Search Seat ===============
# 서울 - 영등포....... Done!
# 영등포 - 수원....... Done!
# 수원 - 평택....... Done!
# 평택 - 천안....... Done!
# 천안 - 조치원....... Done!
# 조치원 - 대전....... Done!
# 대전 - 옥천....... Done!
# 옥천 - 심천....... Done!
# 심천 - 영동....... Done!
# 영동 - 황간....... Done!
# 황간 - 추풍령....... Done!
# 추풍령 - 김천....... Done!
# 김천 - 구미....... Done!
# 구미 - 왜관....... Done!
# 왜관 - 대구....... Done!
# 대구 - 동대구....... Done!
# 동대구 - 경산....... Done!
# 경산 - 청도....... Done!
# 청도 - 상동....... Done!
# 상동 - 밀양....... Done!
# 밀양 - 삼랑진....... Done!
# 삼랑진 - 물금....... Done!
# 물금 - 구포....... Done!
# 구포 - 부산....... Done!

# %%
# 출력
# %matplotlib inline

ko.processing_seat()
ko.visualization()
